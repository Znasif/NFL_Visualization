# %% [markdown]
# #Old version

# %%
# !pip install ColabTurtlePlus
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ColabTurtlePlus
#   Downloading ColabTurtlePlus-2.0.1-py3-none-any.whl (31 kB)
# Installing collected packages: ColabTurtlePlus
# Successfully installed ColabTurtlePlus-2.0.1

# %%
from ColabTurtlePlus.Turtle import *
# Out:
# Put clearscreen() as the first line in a cell (after the import command) to re-run turtle commands in the cell

# %%
clearscreen()
setup(300,300)
showborder()
color("red", "yellow")
shape("turtle")
pensize(2)
speed(7)
begin_fill()
for _ in range(4):
  forward(100)
  left(90)
circle(-50)
end_fill()
color("black","green")
saveSVG(turtle=True)
# Out:
#       <svg width="300" height="300">
#         <rect width="100%" height="100%" style="fill:white;stroke:gray;stroke-width:1"/>
#
#
#         <path fill-rule="evenodd" fill-opacity="1" d="M 150.0 150.0  L 250.0 150.0  L 250.0 50.0  L 150.0 50.0  L 150.0 150.0  A -50 -50 0 0 1 150.0 250.0  A -50 -50 0 0 1 150.0 150.0 " stroke-linecap="round" style="stroke:red;stroke-width:2" fill="yellow" />
#
#
#         <g id="turtle" visibility="visible" transform="rotate(90.0,150.0,150.0) translate(150.0, 150.0)">
# <path style="stroke:black;fill-rule:evenodd;fill:green;fill-opacity:1;" transform="skewX(0) scale(1,1)" d="m 1.1536693,-18.56101 c -2.105469,1.167969 -3.203125,3.441407 -3.140625,6.5 l 0.011719,0.519532 -0.300782,-0.15625 c -1.308594,-0.671875 -2.828125,-0.824219 -4.378906,-0.429688 -1.9375,0.484375 -3.8906253,2.089844 -6.0117193,4.9257825 -1.332031,1.785156 -1.714843,2.644531 -1.351562,3.035156 l 0.113281,0.125 h 0.363281 c 0.71875,0 1.308594,-0.265625 4.6679693,-2.113282 1.199219,-0.660156 2.183594,-1.199218 2.191406,-1.199218 0.00781,0 -0.023437,0.089844 -0.074218,0.195312 -0.472657,1.058594 -1.046876,2.785156 -1.335938,4.042969 -1.054688,4.574219 -0.351562,8.453125 2.101562,11.582031 0.28125,0.355469 0.292969,0.253906 -0.097656,0.722656 -2.046875,2.4609375 -3.027344,4.8984375 -2.734375,6.8046875 0.050781,0.339844 0.042969,0.335938 0.679688,0.335938 2.023437,0 4.15625,-1.316407 6.21875,-3.835938 0.222656,-0.269531 0.191406,-0.261719 0.425781,-0.113281 0.730469,0.46875 2.460938,1.390625 2.613281,1.390625 0.160157,0 1.765625,-0.753906 2.652344,-1.246094 0.167969,-0.09375 0.308594,-0.164062 0.308594,-0.160156 0.066406,0.105468 0.761719,0.855468 1.085937,1.171875 1.613282,1.570312 3.339844,2.402343 5.3593747,2.570312 0.324219,0.02734 0.355469,0.0078 0.425781,-0.316406 0.375,-1.742187 -0.382812,-4.058594 -2.1445307,-6.5585935 l -0.320312,-0.457031 0.15625,-0.183594 c 3.2460927,-3.824218 3.4335927,-9.08593704 0.558593,-15.816406 l -0.050781,-0.125 1.7382807,0.859375 c 3.585938,1.773437 4.371094,2.097656 5.085938,2.097656 0.945312,0 0.75,-0.863281 -0.558594,-2.507812 C 11.458356,-11.838353 8.3333563,-13.268041 4.8607003,-11.721166 l -0.363281,0.164063 0.019531,-0.09375 c 0.121094,-0.550781 0.183594,-1.800781 0.121094,-2.378907 -0.203125,-1.867187 -1.035157,-3.199218 -2.695313,-4.308593 -0.523437,-0.351563 -0.546875,-0.355469 -0.789062,-0.222657" />
# </g>
#       </svg>

# %%
clearscreen()
setup(width=800, height=600)
bgcolor("green")
showborder()

# Create the ball turtle
ball = Turtle()
ball.shape("circle")
ball.color("white")
ball.penup()

# Set the initial position and velocity of the ball
ball.goto(0, 0)
vx = 2  # Horizontal velocity component
vy = 1  # Vertical velocity component

# Simulate the ball movement
while True:
    # Update the ball's position
    ball.goto(ball.xcor() + vx, ball.ycor() + vy)

    # Check for collision with the walls
    if ball.xcor() > 380 or ball.xcor() < -380:
        vx *= -1

    # Check for collision with the walls
    if ball.ycor() > 280 or ball.ycor() < -280:
        vy *= -1

turtle.done()
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:green;stroke:gray;stroke-width:1"/>
#
#
#
#
#
#         <g id="ellipse" visibility="visible" transform="rotate(-90,400.0,300.0) translate(400.0, 300.0)">
# <ellipse transform="skewX(0) scale(1,1)" style="stroke:black;fill:black;stroke-width:1" rx="10" ry = "10" cx="0" cy="0" />
# </g>
#       </svg>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-30e5219558c2> in <cell line: 8>()
#       6 # Create the ball turtle
#       7 ball = Turtle()
# ----> 8 ball.shape("circle")
#       9 ball.color("white")
#      10 ball.penup()
#
# /usr/local/lib/python3.10/dist-packages/ColabTurtlePlus/Turtle.py in shape(self, name)
#    2133             raise ValueError('Shape is invalid. Valid options are: ' + str(VALID_TURTLE_SHAPES))
#    2134         self.turtle_shape = name.lower()
# -> 2135         self.screen._updateDrawing(turtle=self)
#    2136
#    2137     # Scale the size of the turtle
#
# /usr/local/lib/python3.10/dist-packages/ColabTurtlePlus/Turtle.py in _updateDrawing(self, turtle, delay)
#     325                 self.drawing_window.update(HTML(self._generateSvgDrawing()))
#     326                 if delay:
# --> 327                     time.sleep(turtle.timeout)
#     328         else:
#     329             self.drawing_window.update(HTML(self._generateSvgDrawing()))
#
# KeyboardInterrupt:

# %%
clearscreen()
setup(width=800, height=600)
bgcolor("green")
showborder()

# Create three ball turtles
num_turtles = 3
turtles = []
colors = ["red", "blue", "yellow"]

for i in range(num_turtles):
    ball = Turtle()
    ball.shape("circle")
    ball.color(colors[i])
    ball.penup()
    ball.goto(-300 + (i * 200), 0)
    turtles.append(ball)

# Set the initial velocity of the first turtle
vx = 20  # Horizontal velocity component
vy = 10  # Vertical velocity component

# Simulate the ball movement
while True:
    for i in range(num_turtles):
        ball = turtles[i]
        ball.goto(ball.xcor() + vx, ball.ycor() + vy)

        # Check for collision with the walls
        if ball.xcor() > 380 or ball.xcor() < -380:
            vx *= -1

        # Check for collision with the walls
        if ball.ycor() > 280 or ball.ycor() < -280:
            vy *= -1

turtle.done()
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:green;stroke:gray;stroke-width:1"/>
#
#
#
#
#
#         <g id="ellipse" visibility="visible" transform="rotate(270.0,320.0000000084709,109.99999999423383) translate(320.0000000084709, 109.99999999423383)">
# <ellipse transform="skewX(0) scale(1,1)" style="stroke:red;fill:red;stroke-width:1" rx="10" ry = "10" cx="0" cy="0" />
# </g><g id="ellipse" visibility="visible" transform="rotate(-90,540.0,120.0) translate(540.0, 120.0)">
# <ellipse transform="skewX(0) scale(1,1)" style="stroke:blue;fill:blue;stroke-width:1" rx="10" ry = "10" cx="0" cy="0" />
# </g><g id="ellipse" visibility="visible" transform="rotate(-90,740.0,120.0) translate(740.0, 120.0)">
# <ellipse transform="skewX(0) scale(1,1)" style="stroke:yellow;fill:yellow;stroke-width:1" rx="10" ry = "10" cx="0" cy="0" />
# </g>
#       </svg>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-ec43e22f9464> in <cell line: 24>()
#      25     for i in range(num_turtles):
#      26         ball = turtles[i]
# ---> 27         ball.goto(ball.xcor() + vx, ball.ycor() + vy)
#      28
#      29         # Check for collision with the walls
#
# /usr/local/lib/python3.10/dist-packages/ColabTurtlePlus/Turtle.py in goto(self, x, y)
#    1180             self.turtle_degree = alpha % 360
#    1181             self.tilt_angle = turtle_angle_orig+self.tilt_angle-alpha
# -> 1182         self.screen._moveToNewPosition((self.screen._convertx(x), self.screen._converty(y)), units, turtle=self)
#    1183         self.tilt_angle = tilt_angle_orig
#    1184         self.turtle_degree = turtle_angle_orig
#
# /usr/local/lib/python3.10/dist-packages/ColabTurtlePlus/Turtle.py in _moveToNewPosition(self, new_pos, units, turtle)
#     362                             pwidth=turtle.pen_width)
#     363                     initial_pos = turtle.turtle_pos
# --> 364                     self._updateDrawing(turtle=turtle)
#     365                     units -= dunits
#     366             else:
#
# /usr/local/lib/python3.10/dist-packages/ColabTurtlePlus/Turtle.py in _updateDrawing(self, turtle, delay)
#     325                 self.drawing_window.update(HTML(self._generateSvgDrawing()))
#     326                 if delay:
# --> 327                     time.sleep(turtle.timeout)
#     328         else:
#     329             self.drawing_window.update(HTML(self._generateSvgDrawing()))
#
# KeyboardInterrupt:

# %%
import random

clearscreen()
setup(width=800, height=600)
bgcolor("green")
showborder()

# Create the ball turtle
ball = Turtle()
ball.shape("circle")
ball.color("white")
ball.penup()

# Create three player turtles
player1 = Turtle()
player1.shape("turtle")
player1.color("red")
player1.penup()
player1.goto(-200, 0)

player2 = Turtle()
player2.shape("turtle")
player2.color("blue")
player2.penup()

player3 = Turtle()
player3.shape("turtle")
player3.color("yellow")
player3.penup()
player3.goto(200, 0)

players = [player1, player2, player3]

# Set the initial ball position and the player with possession
ball.goto(0, 0)
possessor = player1

pass_interval = random.uniform(2, 5)
start_time = time.time()

def pass_ball():
    global possessor

    # Determine the next player to receive the ball
    current_index = players.index(possessor)
    next_index = (current_index + 1) % len(players)
    receiver = players[next_index]

    # Calculate the angle and distance for the ball's trajectory
    angle = random.uniform(20, 70)  # Random angle between 20 and 70 degrees
    distance = random.uniform(100, 200)  # Random distance between 100 and 200 units

    # Calculate the x and y components of the ball's trajectory
    angle_rad = math.radians(angle)
    x = math.cos(angle_rad) * distance
    y = math.sin(angle_rad) * distance

    # Calculate the target position for the ball
    target_x = receiver.xcor() + x
    target_y = receiver.ycor() + y

    # Move the ball to the target position
    ball.goto(target_x, target_y)
    possessor = receiver

    # Generate a new random time interval for the next pass
    pass_interval = random.uniform(2, 5)

# Main game loop
while True:
    # Move the possessor player towards the ball
    possessor.setheading(possessor.towards(ball.position()))
    possessor.forward(2)

    # Check if the ball is missed by the possessor
    if possessor.distance(ball.position()) > 20:
        # Check if any other player catches the missed ball
        for player in players:
            if player != possessor and player.distance(ball.position()) <= 20:
                ball.goto(player.position())
                possessor = player
                break

    for player in players:
        if player != possessor:
            # Calculate the angle for the circular movement pattern
            angle = player.heading() + 2  # Increment the angle by 2 degrees

            # Calculate the radius and distance from the center
            radius = 100  # Radius of the circular movement pattern
            distance = angle * (math.pi / 180) * radius

            # Calculate the new position of the player
            x = math.cos(angle) * distance
            y = math.sin

    # Check if it's time to pass the ball
    elapsed_time = time.time() - start_time
    if elapsed_time >= pass_interval:
        pass_ball()

        # Reset start time and generate new pass interval
        start_time = time.time()
        pass_interval = random.uniform(2, 5)



turtle.done()
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:green;stroke:gray;stroke-width:1"/>
#
#
#
#
#
#         <g id="ellipse" visibility="visible" transform="rotate(270.0,604.509447774949,134.69521545987655) translate(604.509447774949, 134.69521545987655)">
# <ellipse transform="skewX(0) scale(1,1)" style="stroke:white;fill:white;stroke-width:1" rx="10" ry = "10" cx="0" cy="0" />
# </g><g id="turtle" visibility="visible" transform="rotate(392.3059968,258.657,210.43) translate(258.657, 210.43)">
# <path style="stroke:red;fill-rule:evenodd;fill:red;fill-opacity:1;" transform="skewX(0) scale(1,1)" d="m 1.1536693,-18.56101 c -2.105469,1.167969 -3.203125,3.441407 -3.140625,6.5 l 0.011719,0.519532 -0.300782,-0.15625 c -1.308594,-0.671875 -2.828125,-0.824219 -4.378906,-0.429688 -1.9375,0.484375 -3.8906253,2.089844 -6.0117193,4.9257825 -1.332031,1.785156 -1.714843,2.644531 -1.351562,3.035156 l 0.113281,0.125 h 0.363281 c 0.71875,0 1.308594,-0.265625 4.6679693,-2.113282 1.199219,-0.660156 2.183594,-1.199218 2.191406,-1.199218 0.00781,0 -0.023437,0.089844 -0.074218,0.195312 -0.472657,1.058594 -1.046876,2.785156 -1.335938,4.042969 -1.054688,4.574219 -0.351562,8.453125 2.101562,11.582031 0.28125,0.355469 0.292969,0.253906 -0.097656,0.722656 -2.046875,2.4609375 -3.027344,4.8984375 -2.734375,6.8046875 0.050781,0.339844 0.042969,0.335938 0.679688,0.335938 2.023437,0 4.15625,-1.316407 6.21875,-3.835938 0.222656,-0.269531 0.191406,-0.261719 0.425781,-0.113281 0.730469,0.46875 2.460938,1.390625 2.613281,1.390625 0.160157,0 1.765625,-0.753906 2.652344,-1.246094 0.167969,-0.09375 0.308594,-0.164062 0.308594,-0.160156 0.066406,0.105468 0.761719,0.855468 1.085937,1.171875 1.613282,1.570312 3.339844,2.402343 5.3593747,2.570312 0.324219,0.02734 0.355469,0.0078 0.425781,-0.316406 0.375,-1.742187 -0.382812,-4.058594 -2.1445307,-6.5585935 l -0.320312,-0.457031 0.15625,-0.183594 c 3.2460927,-3.824218 3.4335927,-9.08593704 0.558593,-15.816406 l -0.050781,-0.125 1.7382807,0.859375 c 3.585938,1.773437 4.371094,2.097656 5.085938,2.097656 0.945312,0 0.75,-0.863281 -0.558594,-2.507812 C 11.458356,-11.838353 8.3333563,-13.268041 4.8607003,-11.721166 l -0.363281,0.164063 0.019531,-0.09375 c 0.121094,-0.550781 0.183594,-1.800781 0.121094,-2.378907 -0.203125,-1.867187 -1.035157,-3.199218 -2.695313,-4.308593 -0.523437,-0.351563 -0.546875,-0.355469 -0.789062,-0.222657" />
# </g><g id="turtle" visibility="visible" transform="rotate(411.339173,448.422,261.281) translate(448.422, 261.281)">
# <path style="stroke:blue;fill-rule:evenodd;fill:blue;fill-opacity:1;" transform="skewX(0) scale(1,1)" d="m 1.1536693,-18.56101 c -2.105469,1.167969 -3.203125,3.441407 -3.140625,6.5 l 0.011719,0.519532 -0.300782,-0.15625 c -1.308594,-0.671875 -2.828125,-0.824219 -4.378906,-0.429688 -1.9375,0.484375 -3.8906253,2.089844 -6.0117193,4.9257825 -1.332031,1.785156 -1.714843,2.644531 -1.351562,3.035156 l 0.113281,0.125 h 0.363281 c 0.71875,0 1.308594,-0.265625 4.6679693,-2.113282 1.199219,-0.660156 2.183594,-1.199218 2.191406,-1.199218 0.00781,0 -0.023437,0.089844 -0.074218,0.195312 -0.472657,1.058594 -1.046876,2.785156 -1.335938,4.042969 -1.054688,4.574219 -0.351562,8.453125 2.101562,11.582031 0.28125,0.355469 0.292969,0.253906 -0.097656,0.722656 -2.046875,2.4609375 -3.027344,4.8984375 -2.734375,6.8046875 0.050781,0.339844 0.042969,0.335938 0.679688,0.335938 2.023437,0 4.15625,-1.316407 6.21875,-3.835938 0.222656,-0.269531 0.191406,-0.261719 0.425781,-0.113281 0.730469,0.46875 2.460938,1.390625 2.613281,1.390625 0.160157,0 1.765625,-0.753906 2.652344,-1.246094 0.167969,-0.09375 0.308594,-0.164062 0.308594,-0.160156 0.066406,0.105468 0.761719,0.855468 1.085937,1.171875 1.613282,1.570312 3.339844,2.402343 5.3593747,2.570312 0.324219,0.02734 0.355469,0.0078 0.425781,-0.316406 0.375,-1.742187 -0.382812,-4.058594 -2.1445307,-6.5585935 l -0.320312,-0.457031 0.15625,-0.183594 c 3.2460927,-3.824218 3.4335927,-9.08593704 0.558593,-15.816406 l -0.050781,-0.125 1.7382807,0.859375 c 3.585938,1.773437 4.371094,2.097656 5.085938,2.097656 0.945312,0 0.75,-0.863281 -0.558594,-2.507812 C 11.458356,-11.838353 8.3333563,-13.268041 4.8607003,-11.721166 l -0.363281,0.164063 0.019531,-0.09375 c 0.121094,-0.550781 0.183594,-1.800781 0.121094,-2.378907 -0.203125,-1.867187 -1.035157,-3.199218 -2.695313,-4.308593 -0.523437,-0.351563 -0.546875,-0.355469 -0.789062,-0.222657" />
# </g><g id="turtle" visibility="visible" transform="rotate(393.5211022,667.38,198.313) translate(667.38, 198.313)">
# <path style="stroke:yellow;fill-rule:evenodd;fill:yellow;fill-opacity:1;" transform="skewX(0) scale(1,1)" d="m 1.1536693,-18.56101 c -2.105469,1.167969 -3.203125,3.441407 -3.140625,6.5 l 0.011719,0.519532 -0.300782,-0.15625 c -1.308594,-0.671875 -2.828125,-0.824219 -4.378906,-0.429688 -1.9375,0.484375 -3.8906253,2.089844 -6.0117193,4.9257825 -1.332031,1.785156 -1.714843,2.644531 -1.351562,3.035156 l 0.113281,0.125 h 0.363281 c 0.71875,0 1.308594,-0.265625 4.6679693,-2.113282 1.199219,-0.660156 2.183594,-1.199218 2.191406,-1.199218 0.00781,0 -0.023437,0.089844 -0.074218,0.195312 -0.472657,1.058594 -1.046876,2.785156 -1.335938,4.042969 -1.054688,4.574219 -0.351562,8.453125 2.101562,11.582031 0.28125,0.355469 0.292969,0.253906 -0.097656,0.722656 -2.046875,2.4609375 -3.027344,4.8984375 -2.734375,6.8046875 0.050781,0.339844 0.042969,0.335938 0.679688,0.335938 2.023437,0 4.15625,-1.316407 6.21875,-3.835938 0.222656,-0.269531 0.191406,-0.261719 0.425781,-0.113281 0.730469,0.46875 2.460938,1.390625 2.613281,1.390625 0.160157,0 1.765625,-0.753906 2.652344,-1.246094 0.167969,-0.09375 0.308594,-0.164062 0.308594,-0.160156 0.066406,0.105468 0.761719,0.855468 1.085937,1.171875 1.613282,1.570312 3.339844,2.402343 5.3593747,2.570312 0.324219,0.02734 0.355469,0.0078 0.425781,-0.316406 0.375,-1.742187 -0.382812,-4.058594 -2.1445307,-6.5585935 l -0.320312,-0.457031 0.15625,-0.183594 c 3.2460927,-3.824218 3.4335927,-9.08593704 0.558593,-15.816406 l -0.050781,-0.125 1.7382807,0.859375 c 3.585938,1.773437 4.371094,2.097656 5.085938,2.097656 0.945312,0 0.75,-0.863281 -0.558594,-2.507812 C 11.458356,-11.838353 8.3333563,-13.268041 4.8607003,-11.721166 l -0.363281,0.164063 0.019531,-0.09375 c 0.121094,-0.550781 0.183594,-1.800781 0.121094,-2.378907 -0.203125,-1.867187 -1.035157,-3.199218 -2.695313,-4.308593 -0.523437,-0.351563 -0.546875,-0.355469 -0.789062,-0.222657" />
# </g>
#       </svg>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-c69cea1a6213> in <cell line: 70>()
#      98     elapsed_time = time.time() - start_time
#      99     if elapsed_time >= pass_interval:
# --> 100         pass_ball()
#     101
#     102         # Reset start time and generate new pass interval
#
# <ipython-input-22-c69cea1a6213> in pass_ball()
#      61
#      62     # Move the ball to the target position
# ---> 63     ball.goto(target_x, target_y)
#      64     possessor = receiver
#      65
#
# /usr/local/lib/python3.10/dist-packages/ColabTurtlePlus/Turtle.py in goto(self, x, y)
#    1180             self.turtle_degree = alpha % 360
#    1181             self.tilt_angle = turtle_angle_orig+self.tilt_angle-alpha
# -> 1182         self.screen._moveToNewPosition((self.screen._convertx(x), self.screen._converty(y)), units, turtle=self)
#    1183         self.tilt_angle = tilt_angle_orig
#    1184         self.turtle_degree = turtle_angle_orig
#
# /usr/local/lib/python3.10/dist-packages/ColabTurtlePlus/Turtle.py in _moveToNewPosition(self, new_pos, units, turtle)
#     362                             pwidth=turtle.pen_width)
#     363                     initial_pos = turtle.turtle_pos
# --> 364                     self._updateDrawing(turtle=turtle)
#     365                     units -= dunits
#     366             else:
#
# /usr/local/lib/python3.10/dist-packages/ColabTurtlePlus/Turtle.py in _updateDrawing(self, turtle, delay)
#     325                 self.drawing_window.update(HTML(self._generateSvgDrawing()))
#     326                 if delay:
# --> 327                     time.sleep(turtle.timeout)
#     328         else:
#     329             self.drawing_window.update(HTML(self._generateSvgDrawing()))
#
# KeyboardInterrupt:

# %%
from PIL import Image

# Set up the screen
clearscreen()
image_path = "nfl.png"
image = Image.open(image_path)
setup(width=image.width, height=image.height)
bgpic(image_path)
#screen.title("Simultaneous Movement")

# Create the first entity
entity1 = Turtle()
entity1.shape("turtle")
entity1.color("red")
entity1.penup()
entity1.goto(-200, 0)

# Create the second entity
entity2 = Turtle()
entity2.shape("turtle")
entity2.color("blue")
entity2.penup()
entity2.goto(200, 0)

speed=10
entity1.speed(speed)
entity2.speed(speed)

stamp_list = []
initial_alpha = 1.0
alpha_decay = 0.1

# Move the entities simultaneously for 3 seconds
for _ in range(180):  # 3 seconds * 60 frames per second = 180 frames
    # Move entity1
    entity1.forward(2)
    entity1.right(1)

    # Move entity2
    entity2.forward(2)
    entity2.left(1)

    entity1.color("red", (initial_alpha, 0, 0))
    entity1_stamp = entity1.stamp()
    initial_alpha -= alpha_decay

    # Stamp the trail for entity2 and adjust the color alpha
    entity2.color("blue", (initial_alpha, 0, 0))
    entity2_stamp = entity2.stamp()
    initial_alpha -= alpha_decay

    # Clear the oldest stamp after 0.2 seconds (4 frames)
    if initial_alpha <= 0.0:
        entity1.clearstamp(entity1_stamp)
        entity2.clearstamp(entity2_stamp)

# Clear all remaining stamps
for stamp in stamp_list:
    entity1.clearstamp(stamp)
    entity2.clearstamp(stamp)

# Close the turtle graphics window
turtle.done()
# Out:
#       <svg width="1333" height="800">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#
#
#
#
#       </svg>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-4d65aee4deab> in <cell line: 8>()
#       6 image = Image.open(image_path)
#       7 setup(width=image.width, height=image.height)
# ----> 8 bgpic(image_path)
#       9 #screen.title("Simultaneous Movement")
#      10
#
# NameError: name 'bgpic' is not defined

# %% [markdown]
# #New Version

# %%
import pandas as pd
# Import libraries
import pygame # A python library for creating graphical user interfaces
import math # A python library for mathematical functions
# Out:
# pygame 2.5.1 (SDL 2.28.2, Python 3.10.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
class NFL:
  def __init__(self):
    """
    https://www.kaggle.com/competitions/nfl-big-data-bowl-2022/data
    """
    self.game_link = "https://gist.githubusercontent.com/f-banda/0a7448ddba470ee6009e8bbaf4751a34/raw/56d07b202921b591e8c2390048758c4b3fd3df7b/games.csv"
    self.play_link = "https://gist.githubusercontent.com/f-banda/0a7448ddba470ee6009e8bbaf4751a34/raw/56d07b202921b591e8c2390048758c4b3fd3df7b/plays.csv"
    self.player_link = "https://gist.githubusercontent.com/f-banda/0a7448ddba470ee6009e8bbaf4751a34/raw/56d07b202921b591e8c2390048758c4b3fd3df7b/players.csv"
    self.track_link = "https://dl.dropboxusercontent.com/s/0jvkqf9wnfjdlrf/dataTracking2020.csv"
    self.download()

  def download(self):
    self.game = pd.read_csv(self.game_link)
    self.play = pd.read_csv(self.play_link)
    self.player = pd.read_csv(self.player_link)
    self.track = pd.read_csv(self.track_link)

  def import_pbp_data(self, ls):
    season = self.game[self.game["season"].isin(ls)]
    game = self.play[self.play["gameId"].isin(season["gameId"])]
    play = self.track
    return play

# %%
nfl = NFL()

# %%
# Define constants
WIDTH = 800 # The width of the window
HEIGHT = 600 # The height of the window
FPS = 60 # The frames per second of the animation
SCALE = 10 # The scale factor for converting yards to pixels
OFFSET = 50 # The offset for the field boundaries
WHITE = (255, 255, 255) # The color white
BLACK = (0, 0, 0) # The color black
GREEN = (0, 128, 0) # The color green
YELLOW = (255, 255, 0) # The color yellow
RED = (255, 0, 0) # The color red
BLUE = (0, 0, 255) # The color blue

# %%
# Initialize pygame and create window
pygame.init()
screen = pygame.display.set_mode((WIDTH, HEIGHT))
pygame.display.set_caption("NFL Data Visualization")
clock = pygame.time.Clock()

# %%
nfl.track
# Out:
#                            time       x      y     s     a   dis      o  \
# 0       2020-09-11T00:28:16.900   43.80  17.92  0.09  0.09  0.01  83.30
# 1       2020-09-11T00:28:17.000   43.80  17.92  0.08  0.08  0.01  84.39
# 2       2020-09-11T00:28:17.100   43.81  17.90  0.14  0.18  0.02  84.39
# 3       2020-09-11T00:28:17.200   43.81  17.89  0.14  0.12  0.01  84.39
# 4       2020-09-11T00:28:17.300   43.82  17.89  0.09  0.06  0.01  83.20
# ...                         ...     ...    ...   ...   ...   ...    ...
# 654621  2020-09-15T05:22:39.200  117.23  32.02  1.13  0.85  0.12    NaN
# 654622  2020-09-15T05:22:39.300  117.31  32.10  1.17  0.86  0.12    NaN
# 654623  2020-09-15T05:22:39.400  117.40  32.18  1.14  0.62  0.11    NaN
# 654624  2020-09-15T05:22:39.500  117.48  32.25  1.05  0.43  0.11    NaN
# 654625  2020-09-15T05:22:39.600  117.55  32.32  1.01  0.44  0.10    NaN
#
#            dir      event    nflId      displayName  jerseyNumber position  \
# 0       131.72       None  37211.0  Anthony Sherman          42.0       FB
# 1       127.16       None  37211.0  Anthony Sherman          42.0       FB
# 2       157.21       None  37211.0  Anthony Sherman          42.0       FB
# 3       153.94       None  37211.0  Anthony Sherman          42.0       FB
# 4       152.98       None  37211.0  Anthony Sherman          42.0       FB
# ...        ...        ...      ...              ...           ...      ...
# 654621     NaN       None      NaN         football           NaN      NaN
# 654622     NaN       None      NaN         football           NaN      NaN
# 654623     NaN  touchback      NaN         football           NaN      NaN
# 654624     NaN       None      NaN         football           NaN      NaN
# 654625     NaN       None      NaN         football           NaN      NaN
#
#             team  frameId      gameId  playId playDirection
# 0           home        1  2020091000      39         right
# 1           home        2  2020091000      39         right
# 2           home        3  2020091000      39         right
# 3           home        4  2020091000      39         right
# 4           home        5  2020091000      39         right
# ...          ...      ...         ...     ...           ...
# 654621  football       81  2020091401    4280         right
# 654622  football       82  2020091401    4280         right
# 654623  football       83  2020091401    4280         right
# 654624  football       84  2020091401    4280         right
# 654625  football       85  2020091401    4280         right
#
# [654626 rows x 18 columns]

# %%
# Load data
pbp_data = nfl.import_pbp_data([2020]) # Import play-by-play data for 2020 season
game_id = 2020091000 # Select a game id to visualize
game_data = pbp_data[pbp_data["gameId"] == game_id] # Filter the data by game id
play_id = 612 # Select a play id to visualize
play_data = game_data[game_data["playId"] == play_id] # Filter the data by play id

# %%
# Draw field
def draw_field():
    screen.fill(GREEN) # Fill the screen with green color
    pygame.draw.rect(screen, WHITE, (OFFSET, OFFSET, WIDTH - OFFSET * 2, HEIGHT - OFFSET * 2), 5) # Draw the field boundary with white color and 5 pixels width
    pygame.draw.line(screen, WHITE, (WIDTH / 2, OFFSET), (WIDTH / 2, HEIGHT - OFFSET), 5) # Draw the midfield line with white color and 5 pixels width
    pygame.draw.line(screen, WHITE, (OFFSET + SCALE * 10, OFFSET), (OFFSET + SCALE * 10, HEIGHT - OFFSET), 5) # Draw the left end zone line with white color and 5 pixels width
    pygame.draw.line(screen, WHITE, (WIDTH - OFFSET - SCALE * 10, OFFSET), (WIDTH - OFFSET - SCALE * 10, HEIGHT - OFFSET), 5) # Draw the right end zone line with white color and 5 pixels width

    for i in range(1, 10): # For each yard line from 10 to 90
        x = OFFSET + SCALE * (i * 10 + 10) # Calculate the x coordinate of the yard line
        pygame.draw.line(screen, WHITE, (x, OFFSET), (x, HEIGHT - OFFSET)) # Draw the yard line with white color

        if i % 5 == 0: # If the yard line is a multiple of five
            font = pygame.font.SysFont("Arial", 20) # Create a font object with Arial font and size 20
            text = font.render(str(i * 10), True, WHITE) # Create a text object with the yard number and white color
            screen.blit(text, (x - text.get_width() / 2, OFFSET / 2)) # Blit the text object on the top of the yard line

            text = font.render(str(100 - i * 10), True, WHITE) # Create a text object with the opposite yard number and white color
            screen.blit(text, (x - text.get_width() / 2, HEIGHT - OFFSET / 2 - text.get_height())) # Blit the text object on the bottom of the yard line

# Draw players and ball
def draw_players_and_ball(frame):
    frame_data = play_data[play_data["frame_id"] == frame] # Filter the data by frame id

    for index, row in frame_data.iterrows(): # For each row in the frame data

        x = row["x"] * SCALE + WIDTH / 2 # Convert the x coordinate from yards to pixels and center it on the screen
        y = row["y"] * SCALE + HEIGHT / 2 # Convert the y coordinate from yards to pixels and center it on the screen

        if math.isnan(row["nfl_id"]): # If the row is the ball
            pygame.draw.circle(screen, YELLOW, (x, y), 5) # Draw a yellow circle with radius 5 pixels
        else: # If the row is a player
            if row["team"] == "home": # If the player is on the home team
                color = RED # Use red color
            elif row["team"] == "away": # If the player is on the away team
                color = BLUE # Use blue color
            else: # If the player is on neither team (should not happen)
                color = WHITE # Use white color

            pygame.draw.circle(screen, color, (x, y), 10) # Draw a colored circle with radius 10 pixels
            font = pygame.font.SysFont("Arial", 15) # Create a font object with Arial font and size 15
            text = font.render(str(row["jersey_number"]), True, WHITE) # Create a text object with the jersey number and white color
            screen.blit(text, (x - text.get_width() / 2, y - text.get_height() / 2)) # Blit the text object on the center of the circle

# %%
# Main loop
running = True # A flag to indicate whether the program is running or not
frame = 1 # A variable to store the current frame id
max_frame = play_data["frame_id"].max() # A variable to store the maximum frame id

while running: # While the program is running
    clock.tick(FPS) # Limit the loop to run at FPS times per second

    for event in pygame.event.get(): # For each event in the event queue
        if event.type == pygame.QUIT: # If the event is quitting the program
            running = False # Set the running flag to False

    draw_field() # Draw the field
    draw_players_and_ball(frame) # Draw the players and ball for the current frame

    frame += 1 # Increment the frame by one

    if frame > max_frame: # If the frame exceeds the maximum frame
        frame = 1 # Reset the frame to one

    pygame.display.flip() # Update the display

pygame.quit() # Quit pygame
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'frame_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-616360dca3ce> in <cell line: 4>()
#       2 running = True # A flag to indicate whether the program is running or not
#       3 frame = 1 # A variable to store the current frame id
# ----> 4 max_frame = play_data["frame_id"].max() # A variable to store the maximum frame id
#       5
#       6 while running: # While the program is running
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'frame_id'
